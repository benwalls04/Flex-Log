# %%
import pandas as pd
import sqlite3

# %%
import os

try:
    SCRIPT_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    # __file__ doesn't exist (e.g., in Jupyter)
    SCRIPT_DIR = os.getcwd()  # use current working directory

LOCAL_DB_PATH = os.path.join(
    os.path.dirname(os.path.dirname(os.path.dirname(SCRIPT_DIR))),
    "data",
    "test_database.db"
)

DB_PATH = os.getenv("DATABASE_PATH", LOCAL_DB_PATH)
print(f"Using database path: {DB_PATH}")
# Out:
# Using database path: c:\Users\benwa\OneDrive\Desktop\side_projects\FlexLog\data\test_database.db

# %%
def get_input_features(user_id: int):
  with sqlite3.connect(DB_PATH) as conn:
    cursor = conn.cursor()
    cursor.execute("""
        SELECT 
            l.timestamp, l.first,
            w.name as workout_name,
            e.variant,
            e.machine_type,
            e.name as exercise_name,
            e.chest, e.back, e.legs, e.shoulders, e.biceps, e.triceps, e.misc_group,
            e.barbell, e.dumbbell, e.machine, e.cable, e.smith, e.misc_machine,
            e.isolation, e.compound
        FROM logs l
        JOIN exercises e ON l.exercise_id = e.id
        JOIN workouts w ON l.workout_id = w.id
        WHERE l.user_id = ?
        GROUP BY l.exercise_id, l.workout_id
        ORDER BY l.timestamp ASC
    """, (user_id,))
    rows = cursor.fetchall()
    return rows

# %%
rows = get_input_features(1)

column_names = [
    "timestamp", "first", "workout_name", 
    "variant", "machine_type", "exercise_name",
    "chest","back","legs","shoulders","biceps","triceps","misc_group",
    "barbell","dumbbell","machine","cable","smith","misc_machine",
    "isolation","compound"
]

df = pd.DataFrame(rows, columns=column_names)

df
# Out:
#               timestamp  first             workout_name     variant  \
# 0   2026-01-06 18:00:00      1  chest shoulders trcieps
# 1   2026-01-06 18:20:00      0  chest shoulders trcieps        rope
# 2   2026-01-06 18:50:00      0  chest shoulders trcieps
# 3   2026-01-06 19:10:00      0  chest shoulders trcieps
# 4   2026-01-06 19:30:00      0  chest shoulders trcieps  single-arm
# 5   2026-01-06 20:00:00      0  chest shoulders trcieps
# 6   2026-01-06 20:30:00      0  chest shoulders trcieps
# 7   2026-01-08 18:00:00      1             back biceps         rope
# 8   2026-01-08 18:30:00      0             back biceps
# 9   2026-01-08 18:50:00      0             back biceps
# 10  2026-01-08 19:10:00      0             back biceps
# 11  2026-01-08 19:40:00      0             back biceps
# 12  2026-01-10 18:00:00      1  chest biceps shoulders     standing
# 13  2026-01-10 18:20:00      0  chest biceps shoulders
# 14  2026-01-10 18:50:00      0  chest biceps shoulders   single-arm
# 15  2026-01-10 19:10:00      0  chest biceps shoulders         rope
# 16  2026-01-10 19:30:00      0  chest biceps shoulders      incline
# 17  2026-01-10 19:50:00      0  chest biceps shoulders         rope
# 18  2026-01-11 18:00:00      1             back triceps
# 19  2026-01-11 18:20:00      0             back triceps
# 20  2026-01-11 18:40:00      0             back triceps        rope
# 21  2026-01-11 19:10:00      0             back triceps
# 22  2026-01-11 19:40:00      0             back triceps
# 23  2026-01-13 18:00:00      1  chest shoulders trcieps
# 24  2026-01-13 18:20:00      0  chest shoulders trcieps  single-arm
# 25  2026-01-13 18:50:00      0  chest shoulders trcieps
# 26  2026-01-13 19:10:00      0  chest shoulders trcieps
# 27  2026-01-13 19:30:00      0  chest shoulders trcieps        rope
# 28  2026-01-13 20:00:00      0  chest shoulders trcieps
# 29  2026-01-15 18:00:00      1             back biceps         rope
# 30  2026-01-15 18:30:00      0             back biceps
# 31  2026-01-15 19:00:00      0             back biceps
# 32  2026-01-15 19:20:00      0             back biceps
# 33  2026-01-15 19:40:00      0             back biceps
# 34  2026-01-15 20:10:00      0             back biceps
# 35  2026-01-17 18:00:00      1  chest biceps shoulders
# 36  2026-01-17 18:30:00      0  chest biceps shoulders         rope
# 37  2026-01-17 18:50:00      0  chest biceps shoulders     standing
# 38  2026-01-17 19:20:00      0  chest biceps shoulders
# 39  2026-01-17 19:50:00      0  chest biceps shoulders
# 40  2026-01-17 20:10:00      0  chest biceps shoulders         rope
# 41  2026-01-18 18:00:00      1             back triceps
# 42  2026-01-18 18:20:00      0             back triceps        rope
# 43  2026-01-18 18:50:00      0             back triceps
# 44  2026-01-18 19:10:00      0             back triceps
#
#    machine_type         exercise_name  chest  back  legs  shoulders  ...  \
# 0      dumbbell         skullcrusher       0     0     0          0  ...
# 1                     tricep pushdown      0     0     0          0  ...
# 2       machine           chest press      1     0     0          0  ...
# 3       barbell           bench press      1     0     0          0  ...
# 4         cable        lateral raise       0     0     0          1  ...
# 5      dumbbell       overhead press       0     0     0          1  ...
# 6                cable rear delt fly       0     0     0          0  ...
# 7         cable                  curl      0     0     0          0  ...
# 8      dumbbell           hammer curl      0     0     0          0  ...
# 9                        machine row       0     1     0          0  ...
# 10                      lat pull over      0     1     0          0  ...
# 11                     lat pull down       0     1     0          0  ...
# 12     dumbbell         lateral raise      0     0     0          1  ...
# 13     dumbbell         incline curl       0     0     0          0  ...
# 14        cable        lateral raise       0     0     0          1  ...
# 15        cable                  curl      0     0     0          0  ...
# 16     dumbbell           bench press      1     0     0          0  ...
# 17                    tricep pushdown      0     0     0          0  ...
# 18                      lat pull over      0     1     0          0  ...
# 19                       machine row       0     1     0          0  ...
# 20                    tricep pushdown      0     0     0          0  ...
# 21                     lat pull down       0     1     0          0  ...
# 22     dumbbell           hammer curl      0     0     0          0  ...
# 23      barbell           bench press      1     0     0          0  ...
# 24        cable        lateral raise       0     0     0          1  ...
# 25     dumbbell         skullcrusher       0     0     0          0  ...
# 26      machine           chest press      1     0     0          0  ...
# 27                    tricep pushdown      0     0     0          0  ...
# 28                     lat pull down       0     1     0          0  ...
# 29        cable                  curl      0     0     0          0  ...
# 30                       machine row       0     1     0          0  ...
# 31                     lat pull down       0     1     0          0  ...
# 32               cable rear delt fly       0     0     0          0  ...
# 33     dumbbell           hammer curl      0     0     0          0  ...
# 34                      lat pull over      0     1     0          0  ...
# 35                        pec-dec fly      1     0     0          0  ...
# 36        cable                  curl      0     0     0          0  ...
# 37     dumbbell         lateral raise      0     0     0          1  ...
# 38     dumbbell         incline curl       0     0     0          0  ...
# 39     dumbbell           hammer curl      0     0     0          0  ...
# 40                    tricep pushdown      0     0     0          0  ...
# 41               cable rear delt fly       0     0     0          0  ...
# 42                    tricep pushdown      0     0     0          0  ...
# 43                       machine row       0     1     0          0  ...
# 44                      lat pull over      0     1     0          0  ...
#
#     triceps  misc_group  barbell  dumbbell  machine  cable  smith  \
# 0         1           0        0         1        0      0      0
# 1         1           0        0         0        0      1      0
# 2         0           0        0         0        1      0      0
# 3         0           0        1         0        0      0      0
# 4         0           0        0         0        0      1      0
# 5         0           0        0         1        0      0      0
# 6         0           1        0         0        0      1      0
# 7         0           0        0         0        0      1      0
# 8         0           0        0         1        0      0      0
# 9         0           0        0         0        1      0      0
# 10        0           0        0         0        0      1      0
# 11        0           0        0         0        0      0      0
# 12        0           0        0         1        0      0      0
# 13        0           0        0         1        0      0      0
# 14        0           0        0         0        0      1      0
# 15        0           0        0         0        0      1      0
# 16        0           0        0         1        0      0      0
# 17        1           0        0         0        0      1      0
# 18        0           0        0         0        0      1      0
# 19        0           0        0         0        1      0      0
# 20        1           0        0         0        0      1      0
# 21        0           0        0         0        0      0      0
# 22        0           0        0         1        0      0      0
# 23        0           0        1         0        0      0      0
# 24        0           0        0         0        0      1      0
# 25        1           0        0         1        0      0      0
# 26        0           0        0         0        1      0      0
# 27        1           0        0         0        0      1      0
# 28        0           0        0         0        0      0      0
# 29        0           0        0         0        0      1      0
# 30        0           0        0         0        1      0      0
# 31        0           0        0         0        0      0      0
# 32        0           1        0         0        0      1      0
# 33        0           0        0         1        0      0      0
# 34        0           0        0         0        0      1      0
# 35        0           0        0         0        1      0      0
# 36        0           0        0         0        0      1      0
# 37        0           0        0         1        0      0      0
# 38        0           0        0         1        0      0      0
# 39        0           0        0         1        0      0      0
# 40        1           0        0         0        0      1      0
# 41        0           1        0         0        0      1      0
# 42        1           0        0         0        0      1      0
# 43        0           0        0         0        1      0      0
# 44        0           0        0         0        0      1      0
#
#     misc_machine  isolation  compound
# 0              0          1         0
# 1              0          1         0
# 2              0          0         1
# 3              0          0         1
# 4              0          1         0
# 5              0          0         1
# 6              0          1         0
# 7              0          1         0
# 8              0          1         0
# 9              0          0         1
# 10             0          1         0
# 11             1          0         1
# 12             0          1         0
# 13             0          1         0
# 14             0          1         0
# 15             0          1         0
# 16             0          0         1
# 17             0          1         0
# 18             0          1         0
# 19             0          0         1
# 20             0          1         0
# 21             1          0         1
# 22             0          1         0
# 23             0          0         1
# 24             0          1         0
# 25             0          1         0
# 26             0          0         1
# 27             0          1         0
# 28             1          0         1
# 29             0          1         0
# 30             0          0         1
# 31             1          0         1
# 32             0          1         0
# 33             0          1         0
# 34             0          1         0
# 35             0          1         0
# 36             0          1         0
# 37             0          1         0
# 38             0          1         0
# 39             0          1         0
# 40             0          1         0
# 41             0          1         0
# 42             0          1         0
# 43             0          0         1
# 44             0          1         0
#
# [45 rows x 21 columns]

# %%
df["exercise_name"] = df["variant"] + " " +  df["machine_type"] + " " + df["exercise_name"]

muscle_groups = ["chest", "back", "legs", "shoulders", "biceps", "triceps"]

for group in muscle_groups: 
  df[f"{group}_day"] = df["workout_name"].str.contains(group, case=False).astype(int)

# %%
lagged_cols = ["barbell", "dumbbell", "machine", "cable", "smith", "misc_machine", "misc_group", "isolation", "compound", "chest", "back", "legs", "shoulders", "biceps", "triceps"]

for col in lagged_cols:
    df[f"prev_{col}"] = (
        df[col]
        .shift(1)
        .fillna(0)
        .astype(int)
    )

    df.loc[df["first"] == 1, f"prev_{col}"] = 0

# %%
feature_cols = [col for col in df.columns if col.startswith("prev_") or "day" in col]

X = df[feature_cols].values
y_muscle = df[["chest", "back", "legs", "shoulders", "biceps", "triceps", "misc_group"]]
y_machine = df[["barbell", "dumbbell", "machine", "cable", "smith", "misc_machine"]]
y_type = df[["isolation", "compound"]]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# ------------------------------------------------------------------
# 1. SINGLE train/test split using DataFrame indices
# ------------------------------------------------------------------

train_idx, test_idx = train_test_split(
    df.index,
    test_size=0.4,
    random_state=42
)

X_train = X[train_idx]
X_test  = X[test_idx]

y_muscle_train  = y_muscle.iloc[train_idx]
y_muscle_test   = y_muscle.iloc[test_idx]

y_machine_train = y_machine.iloc[train_idx]
y_machine_test  = y_machine.iloc[test_idx]

y_type_train    = y_type.iloc[train_idx]
y_type_test     = y_type.iloc[test_idx]

# Keep aligned DataFrame rows
test_df = df.loc[test_idx]

# ------------------------------------------------------------------
# 2. Train Ridge models
# ------------------------------------------------------------------

ridge_muscle  = Ridge(alpha=1.0).fit(X_train, y_muscle_train)
ridge_machine = Ridge(alpha=1.0).fit(X_train, y_machine_train)
ridge_type    = Ridge(alpha=1.0).fit(X_train, y_type_train)

# ------------------------------------------------------------------
# 3. Predict + argmax
# ------------------------------------------------------------------

y_muscle_pred_class  = ridge_muscle.predict(X_test).argmax(axis=1)
y_machine_pred_class = ridge_machine.predict(X_test).argmax(axis=1)
y_type_pred_class    = ridge_type.predict(X_test).argmax(axis=1)

y_muscle_true_class  = y_muscle_test.to_numpy().argmax(axis=1)
y_machine_true_class = y_machine_test.to_numpy().argmax(axis=1)
y_type_true_class    = y_type_test.to_numpy().argmax(axis=1)

# ------------------------------------------------------------------
# 4. (Optional) Metrics
# ------------------------------------------------------------------

# print("Muscle accuracy:", accuracy_score(y_muscle_true_class, y_muscle_pred_class))
# print("Machine accuracy:", accuracy_score(y_machine_true_class, y_machine_pred_class))
# print("Type accuracy:", accuracy_score(y_type_true_class, y_type_pred_class))

# ------------------------------------------------------------------
# 5. Label decoding
# ------------------------------------------------------------------

muscle_labels  = ["chest","back","legs","shoulders","biceps","triceps","misc_group"]
machine_labels = ["barbell","dumbbell","machine","cable","smith","misc_machine"]
type_labels    = ["isolation","compound"]

predicted_muscle  = [muscle_labels[i] for i in y_muscle_pred_class]
predicted_machine = [machine_labels[i] for i in y_machine_pred_class]
predicted_type    = [type_labels[i] for i in y_type_pred_class]

# ------------------------------------------------------------------
# 6. Decode prev_* features
# ------------------------------------------------------------------

def get_prev_from_onehot(row, labels, prefix):
    for label in labels:
        if row[f"{prefix}{label}"] == 1:
            return label
    return "none"

final_df = pd.DataFrame({
    "prev_muscle":  test_df.apply(lambda r: get_prev_from_onehot(r, muscle_labels, "prev_"), axis=1),
    "prev_machine": test_df.apply(lambda r: get_prev_from_onehot(r, machine_labels, "prev_"), axis=1),
    "prev_type":    test_df.apply(lambda r: get_prev_from_onehot(r, type_labels, "prev_"), axis=1),
    "workout_name": test_df["workout_name"],
    "next_group":   predicted_muscle,
    "next_machine": predicted_machine,
    "next_type":    predicted_type
})

final_df
# Out:
#    prev_muscle  prev_machine  prev_type             workout_name next_group  \
# 39      biceps      dumbbell  isolation  chest biceps shoulders     triceps
# 25   shoulders         cable  isolation  chest shoulders trcieps  shoulders
# 26     triceps      dumbbell  isolation  chest shoulders trcieps    triceps
# 43     triceps         cable  isolation             back triceps       back
# 35        none          none       none  chest biceps shoulders      biceps
# 41        none          none       none             back triceps       back
# 4        chest       barbell   compound  chest shoulders trcieps    triceps
# 12        none          none       none  chest biceps shoulders      biceps
# 8       biceps         cable  isolation             back biceps        back
# 3        chest       machine   compound  chest shoulders trcieps    triceps
# 6    shoulders      dumbbell   compound  chest shoulders trcieps    triceps
# 24       chest       barbell   compound  chest shoulders trcieps    triceps
# 32        back  misc_machine   compound             back biceps      biceps
# 19        back         cable  isolation             back triceps       back
# 17       chest      dumbbell   compound  chest biceps shoulders     triceps
# 13   shoulders      dumbbell  isolation  chest biceps shoulders      biceps
# 42  misc_group         cable  isolation             back triceps     biceps
# 15   shoulders         cable  isolation  chest biceps shoulders      biceps
#
#     next_machine  next_type
# 39         cable  isolation
# 25      dumbbell   compound
# 26         cable  isolation
# 43  misc_machine   compound
# 35         cable  isolation
# 41         cable  isolation
# 4          cable  isolation
# 12         cable  isolation
# 8        machine   compound
# 3          cable  isolation
# 6       dumbbell  isolation
# 24         cable  isolation
# 32      dumbbell  isolation
# 19  misc_machine   compound
# 17         cable  isolation
# 13      dumbbell  isolation
# 42      dumbbell  isolation
# 15      dumbbell   compound
